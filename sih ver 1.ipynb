# %%
import pandas as pd
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Downloads/ATom1_flight_tracks.csv')
df2 = pd.read_csv('Downloads/abc2.csv')

# %%
print(df.head(1))
print(df2.head(1))
# Out:
#      #index  RF  YYYYMMDD  UTC_Start  UTC_Stop  Latitude  Longitude  \
# 0  A1_00001   1  20160729    52390.0   52400.0  34.63096 -118.10735
#
#    Altitude (m masl GPS)     P (hPa)    T(K)  CumDist (km)
# 0             799.533333  922.293333  303.09      0.190934
#    Plane Number  Latitude   Longitude   Altitude   Velocity   Time
# 0             0     -13594       -9455         27         82      0

# %%
df2[0:100]
# Out:
#     Plane Number  Latitude   Longitude   Altitude   Velocity   Time
# 0              0     -13594       -9455         27         82      0
# 1              0     -13925       -9255         71         82      4
# 2              0     -14265       -9055        117         84      8
# 3              0     -14615       -8853        163         86     13
# 4              0     -14974       -8651        207         88     17
# ..           ...        ...         ...        ...        ...    ...
# 95             0      12281       20298       5374        217    439
# 96             0      13267       20514       5443        217    444
# 97             0      14253       20725       5508        217    448
# 98             0      15240       20937       5568        217    453
# 99             0      16230       21150       5623        217    458
#
# [100 rows x 6 columns]

# %%
t1=np.array
t1=df2[['Latitude ','Longitude ','Altitude ']]
#t1.append(df['Longitude'])
#t1=t1[15143:18978]
#t1=t1[0:107]
#t1=t1[108:267]
#t1=t1[268:489]
#t1=t1[490:563]
#t1=t1[564:728]
#t1=t1[729:847]
#t1=t1[848:920]
#t1=t1[921:1136]
#t1=t1[1137:1403]
t1=t1[1404:1429]
t1
# Out:
#       Latitude   Longitude   Altitude
# 1404     -13137       11186        301
# 1405     -13213       10864        301
# 1406     -13280       10581        301
# 1407     -13342       10315        301
# 1408     -13407       10058        301
# 1409     -13487        9813        301
# 1410     -13594        9584        301
# 1411     -13733        9371        301
# 1412     -13898        9178        300
# 1413     -14081        9004        299
# 1414     -14278        8841        295
# 1415     -14483        8681        287
# 1416     -14691        8523        279
# 1417     -14898        8372        274
# 1418     -15103        8221        271
# 1419     -15301        8063        271
# 1420     -15478        7890        271
# 1421     -15621        7690        271
# 1422     -15729        7466        271
# 1423     -15809        7225        271
# 1424     -15881        6976        271
# 1425     -15968        6725        271
# 1426     -16067        6473        271
# ...

# %%
ax = plt.axes(projection='3d')

ax.plot3D(t1['Latitude '],t1['Longitude '],t1['Altitude '])
  #   rstride=1, cstride=1,
   # facecolors=cm.jet(N),
    #linewidth=0, antialiased=False, shade=False)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
#plt.zlabel('Altitude')
plt.show()

# %%
df2 = pd.read_excel('Downloads/ne.xlsx')

# %%
df2
# Out:
#        lon    lat   alt
# 0    70976  30586  3230
# 1    70251  30500  3230
# 2    69526  30406  3230
# 3    68796  30318  3230
# 4    68060  30248  3229
# ..     ...    ...   ...
# 205  -2327   2232    84
# 206  -2095   2037    69
# 207  -1862   1842    54
# 208  -1631   1648    42
# 209  -1400   1454    32
#
# [210 rows x 3 columns]

# %%
t2=np.array
t2=df2[['lat','lon','alt']]
#t1.append(df['Longitude'])
#t2=t2[15143:18978]
#t1=t1[0:500]
#t2=t2[110:130]

# %%
ax = plt.axes(projection='3d')

ax.scatter3D(t2['lat'],t2['lon'],t2['alt'])
  #   rstride=1, cstride=1,
   # facecolors=cm.jet(N),
    #linewidth=0, antialiased=False, shade=False)
plt.xlabel('Latitude')
plt.ylabel('Longitude')
#plt.zlabel('Altitude')
plt.show()

# %%
data = pd.read_csv('Downloads/LibreOffice Calc.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e56d36fd3ed8> in <module>
# ----> 1 data = pd.read_csv('Downloads/LibreOffice Calc.csv')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# ...
